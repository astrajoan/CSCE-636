# %% [markdown]
# <a href="https://colab.research.google.com/github/astrajoan/CSCE-636/blob/main/Homework8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text generation: LSTM

# %% [markdown]
# Load dataset

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %% [markdown]
# Preprocess data

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# Build model

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# Train the network and output texts with various temperature in sampling strategy

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 17s 6ms/step - loss: 2.2614
# --- Generating with seed: "ill be unable to
# understand even these combinations.
#
#
# 113
#
# "
# ------ temperature: 0.2
# ill be unable to
# understand even these combinations.
#
#
# 113
#
# =a the conscience of the senses and will of the sense in a great a sort of the some an arting and as a part of the say and the sach as a to the sach as the some to the say, and the serman and present of the sense of the say, and the some of the sense is in the say, and the best of the some of the something to the say, and as a to the some and a some the some has to the some the fact of the say, an
# ------ temperature: 0.5
#  and a some the some has to the some the fact of the say, and as instinct of the stranging the sense to the possition to the conscience of the contrary contration to the farsely of which so the sympary a reare plene of reason in the moral intermine of be an interpled and most and against to in of the some of a good of the man he something to has deart of the common to as to the astory of the can the way as a more of the good to a fact of the different his
# ------ temperature: 1.0
# he way as a more of the good to a fact of the different his general noble mashrituly than art destengh to that he cert, stom in forutic
# spones of ascount to zatiented kind and bullar? dy eghing by have toowact things of togouls, the
# spensorial ford be though as himself in others man sla
# powe, it is rowledess atont somi, the imman for
# moral intouther us to the ducarst a buenced, a
# sean, them. xeling who conscient has, philosophy sycmosn
# mensnering to carica
# ------ temperature: 1.2
# g who conscient has, philosophy sycmosn
# mensnering to caricable--"fun of dicle
# musickal does loses
# datictal desbrems for has banctribly oundessy, which wi lie, is dnef,
# f'rriugh of
# this theperfunife, event wes devistr:--han obnowcdored, clorr" hasfewh,
# abther cakable arpled-yenlied who: the beptrualitid, it was sritul cer a mustian, poter oun oge. however it ilad, an
# ebjonce, revensy tor of sa'rivglaty-: yth that who, who one-suritaheration disif  the
# waym
# epoch 2
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.6046
# --- Generating with seed: " of life?--in the end, it is not only
# permitted to make this"
# ------ temperature: 0.2
#  of life?--in the end, it is not only
# permitted to make this something and the strength to the possibility in the contrary and the power to the same to the complete to be the power to the good to the sense and the sense and the concealy and the strength and been to the strength of the same to the sense of the fact the condution of the condution of the strength and such and the still to the same themselves to possible to the possibility to the sense that th
# ------ temperature: 0.5
# emselves to possible to the possibility to the sense that the contemposical complection of the with the point to conceaning to the fact and completentation of the soulsong and
# complater and the stitionable and like to the spirit and the to have the epsision of the state to the completent and the humand
# in the horders
# and be so that the conciance to the
# complecian to souls
# more compare been under the been a false to the sentiments of the possibility to have
# ------ temperature: 1.0
# he been a false to the sentiments of the possibility to have plater. and and
# a
# brebdity,
# whose "fanhingns, was in many unceriate" and being. s"girateh, with understands himself, as
# ture, to boongess yo gost, rang himself single: joybbect and unlife-fluges in the way indeps though to accerable,
# "all wh cents of fims, theqposiou and cysicles handel to subsidelx fooking transposter arened as
# a immentanial will to fext becime has ton, unfrevensian, tempicate a
# ------ temperature: 1.2
# anial will to fext becime has ton, unfrevensian, tempicate and mate nge stal
# , retaked efter
# peadal longing as pramed, find-howhing', deptyoous.sade: aniesvent to domes" certaic in of miny, but everythel, why with felti any
# toopehness come
# haveto=varian goon est "fceation of therebyers's'.
#
#
# 14!t heart posonayy, towards" were
# sare more a: theorow
# pater: which fat be cpostical this ay grogn,
# that i thereby. a
# prifige that
# per?tsl vaining higher and
# those mi
# epoch 3
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.5233
# --- Generating with seed: " ages, which may be proud of their humanity, there
# still rem"
# ------ temperature: 0.2
#  ages, which may be proud of their humanity, there
# still remart of the most the man in the most soul and for the fact the conscious the same the strength and the most really and the result of the most distrust and the fact of the same the most strong the morality of the most the strength in the standard of the most the self-conscious and the most souls and souls and the result the most soulshowed and soulsher and the most the presudicient of the most distr
# ------ temperature: 0.5
# and soulsher and the most the presudicient of the most distrust in free them protain the condition of the disconding our does soul to be which it is the spirit and expression and in the
# sensual and sacrese, and the philosopher which which it is moral of the manifest the ware conscious in the most man is a dispection and judgment of not they who has the will is and its richers of comprehen are to be and probably desire and also an occe of the sense of the m
# ------ temperature: 1.0
# e and probably desire and also an occe of the sense of the morely souls dif
# it and
# lastime indoenk with would knows a seces a condine eyitiate      sway possepsisional little inaring made it is its places in veryould, this presture of noble that we
# was a disply within to a dey the "fine there
# much him ekerumately, the dre in-weaknly barn
# inspired to one mustic and cahee.
# the geed with be which there spaint is moral," hy by self-csanded in the fusule of cal
# ------ temperature: 1.2
# re spaint is moral," hy by self-csanded in the fusule of called made thene gres
# aspiolable many") bees him, as the wi! kenen, then meak, effect in value, and gaff to equcies ambeal longity and from its,
# plent good with it is must id ratisal quely and gradafor and self, now percen
# and hereine of the religim, belong.
#
# oonivers imspires af metapsy elemidea: its tymporair why the
# noboghijary were that it undances irptant pride an instince!--that personand, of
# epoch 4
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4776
# --- Generating with seed: " and german depth is often only a difficult, hesitating
# "dig"
# ------ temperature: 0.2
#  and german depth is often only a difficult, hesitating
# "digning the foreto the same and in the states of the sense of the sentiment to the state of the sense of the destering to be the sentiment in the sense of the fact to be sentiment of the granting in the contrary and sense of the sentiments of the foreto the sense of the fact the sense of the same and present and sense of the sentiments of the sentiment of the sense of the sentiment of the same the se
# ------ temperature: 0.5
# e sentiment of the sense of the sentiment of the same the sentiment of the sense of the essentially labor and dispoint for the most forething that is the disposite and that the delicate stronger to the existence of the disticulons and restraturature and the means of the most places and stine in all the charms and destrusting into the do and be an oxisting the germanisher of the disposite senses to rangeral and delicate man is a sole of the disposit of the
# ------ temperature: 1.0
#  rangeral and delicate man is a sole of the disposit of the esernity and nature, uncow and propless and coar, and worped himself upon the treilists consential are music class a grestipsy are to a  mariy, the woods and soul and implontive upposiant,m! so name the oppress on grattiently and difference experience in the
# sensice, the
# centure! to ex.i
# power to vicile, my form that un is even but dra)
# a good would whiche thought value s
# kind of constraint, group
# ------ temperature: 1.2
#  good would whiche thought value s
# kind of constraint, groupway, in it? and ranger
# to led breathens of paths unl; who eart
# go sourve me wantsrartury, or
#   . ade ho even clesine human goody riberousl: it which
# cress "present
# germann, man.y--whon; why a sander an
# musient, who ha force in hin as
# good ppaitinal, merent mank--even "master sfine sous form of mantfer
# all natured aly are condentay questanisy, of blitter to presest desil anedgen; in the establd.--w
# epoch 5
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4492
# --- Generating with seed: "nally be brought to a close. the time for
# petty politics is "
# ------ temperature: 0.2
# nally be brought to a close. the time for
# petty politics is a subtle the same and the man in the same to the strieity of the desire and the metaphysical sense of the morality of the same and all the same interesting the sense of the same self-supportion of the sense of the more the same one must be seems to the same and the same strie the man and the same and the sense of the desire and all the same and the same to the same interesting of the sensual and i
# ------ temperature: 0.5
# me and the same to the same interesting of the sensual and instance, and the order to be a problem that is deligious and instance the far and sensut of the hundred to the self-entire for and laws and take a sout and impulse sont on the pride, to the spirit of respect to a proud is as if the same of the strifes of the strees of his order of eyes of profound who desire interpretation and and sect its to the moral has not perhaps a rank and the mentary of the
# ------ temperature: 1.0
# s to the moral has not perhaps a rank and the mentary of the miduady overstakes must knows callity--in the health often, it perhaps the
# our as
# algacise timent of upreidage the ertional and doubt: south more tr have been concept of truth? it is such ever immoster fact and
# satifual
# denjuence, -the staped to him, would mowety, thorapsy of thinghed in eyes, sympathy ickleting if to the spirits,
# founds and always seet the spirit he sactives and morally" in the
# ------ temperature: 1.2
#  and always seet the spirit he sactives and morally" in the priftuesmem and good thing and that immenscomity vittrare: en1ution.: it is
# absuddence? ast-goratsed with hard, bregise thrims suffering.
#
#
# it may howidd by repodit be merist armination in
# the ond towards
# you alreablately, we fruth, his tatic and
# to "nature.
#        s hortsman is, every de effect is outs
# "guild--un ganity of the higwantly cou=de to just outs, i. the
# imofil
# of the break other accour
# epoch 6
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4289
# --- Generating with seed: "kes us wet: why then do we term the man who inflicts
# injury "
# ------ temperature: 0.2
# kes us wet: why then do we term the man who inflicts
# injury of the same things and desires and the same than and desiration of the same the have been a stand are the same to the present of the same things and the same things of the same the have no say, and the same that the fact the fact the same will and the same to the same thing and stand as a god and conscious and the conscious and and something and the same that have been and the have a souls and con
# ------ temperature: 0.5
# ing and the same that have been and the have a souls and conscious and conscious and the fashions and anticulosty and have been seem of the conscious of enlightenly with a more and parent of the most the same desires of europears of the same whole the same a world and men and sign as the same also have its art of little all the conscious and aschomal contrary in the delusion in the same instinction and nature and our have the way and there feel and and the
# ------ temperature: 1.0
# n and nature and our have the way and there feel and and the rility, here backhittess
# in moral, that as has stone honout itself shound. on this
# same will advate--whilc have no
# all indepacition that has here great intellectually comprure to need and
# "poligy and
# nobscely and spirit of the entathies in
# the constrain a fach
# is art and culturatory (that it pathy kind beckonation it even their time an.
# cllage, that , a stands
# for at eounder say, of other be diff
# ------ temperature: 1.2
# cllage, that , a stands
# for at eounder say, of other be difficultuateditly, secficule
# and for the cersans, he i asceist becarrudeable without
# to  feally
# namet folledic upiant with a cattrainic ignicate. in goupond casten, which, nowpable; thoughtness hadolo
# to trush place our illoosing:
#
# ill
# freels and "pposimious
# wh, he
# should a relations to
# tain-grdigness, that the stach
# by foracal
# commanding-create: than moralt, which is spoverness, othwidanly catical
# epoch 7
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.4123
# --- Generating with seed: "e and [any] deed by itself is regarded as
# morally ambiguous."
# ------ temperature: 0.2
# e and [any] deed by itself is regarded as
# morally ambiguous. the sense of the still the sense of the strengther of the sense of the sense of the spirit of the sense of the sense of the submect of the more the fact the sense of the present readical experience and the states of the present readical present milled to the senses and all all selfing the sense of the sense of the more the more the more the more more men and the sense of the sense of the same to
# ------ temperature: 0.5
# the more more men and the sense of the sense of the same to the general as the closely and feeling that we feels he who demane the and the spirit of the world of the second the still present reductive the truth.
#
#  han the means of mankind of the
# state of
# a souls and self-contemplation of many have a strengthers as are not the science of certain the same to experience and all literatory, and but the outseless of experience of the science and moral desire as
# ------ temperature: 1.0
# e outseless of experience of the science and moral desire as brute of your cannot been longatedy only of the everlether morality.
#
# 1i1.
# call then not only lie to at in didfering this
# conscients. to consequent, and regards itself. he his factection,--all
# inrelds a kinds of the ptin of matest for intevely.
#
# i3ly is a else the sinded uttifus in our clease a a cle dof become every imonor ideal ever a guess of the such as man to have the deception. it deares, b
# ------ temperature: 1.2
# guess of the such as man to have the deception. it deares, but reginals--wa" been to ad y. understand up
# not find, a kindapliess
# on, yeads.
#  are involted the free bad on the
# sendafeity: the
# sew, to race.
# ,t.thined conmest humanity-1"hup. though he
# forn of explushdes, without!--moral humsman, and see antrars
# for one's simple onshim must their ceptoniying to lostal hulp. and nue understand
# all
# permit longur of
# realority:
# aboune euroahen a tendr(the all conis
# epoch 8
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3981
# --- Generating with seed: "d artistic affinities is very hard to find; still harder,
# th"
# ------ temperature: 0.2
# d artistic affinities is very hard to find; still harder,
# the same with the fact the propess and stren to one has a discomman and all the astent which is a man to deterioration of the same and strife of the containess of the are not an endist the stren to delicate an and strie, and and even the south the senses the stren to a delicate the senses to the same and stren the stren to a something for the fact of the senses of the stren to the stren to an even t
# ------ temperature: 0.5
# he fact of the senses of the stren to the stren to an even the german something means the hand the fance to the belief the god in the commander, it is its world does not been it religion to really philosopher of the experience of the relations of their are in the way of his an another and the perility with the sass of the stren to are the even other pain a necessary conceptions of the conquestical by a do even the latter who propess in the be can suffering
# ------ temperature: 1.0
#  by a do even the latter who propess in the be can suffering there remain inteltaliated at above refalled kind of belition consciant eatenes., thus, who ad ackination with even posity
# and a dedention
# than "so callithernale develoming, who belief,
# his interminated inseless:
#     besisally. the coums
# these promedsabutited are compusious freequent
# and sense of do typrimenced to worlully--owing the
# unexcition:--has an in his healthifoul, re at acts long heth we
# ------ temperature: 1.2
# xcition:--has an in his healthifoul, re at acts long heth wermisty, whe musae it reschonation something go wex:--thet willist
# fahuthe of its, so europeanity for the sensation, there tere has at so them viltifor cause is, af an
# unevatessing
# the right to senst
# man, act wit= at thies.--this
# ill eprompatical condition oin
# man hum), corrous, symece": yet could a imman any existencc is atmi: a so apabt calstratern order so, as                 s quite
# and explini
# epoch 9
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3884
# --- Generating with seed: "asis of which we make everyone responsible, hence, the so-ca"
# ------ temperature: 0.2
# asis of which we make everyone responsible, hence, the so-called the sense of the sense of the same and the most serve the desire the new and the more there is a man the great be and the sense of the reason the sense of the desire and the bood, and the man the sense of the sense of the sense of the same the sense of the sense of the sense of the sense of the more for the result to be the most subtone to his philosophers in the sense of the sense of the sen
# ------ temperature: 0.5
# one to his philosophers in the sense of the sense of the sentiments of the spirit in share a come of the value into more expression of the belief the only enough, and the povertic possible of all in the same translated without his very peopest the philosophy, the also and consideration of the right to be second in the deeding in the most rank and or even the stronger and last now sentiment of the descartion of the same with the age the most rational intell
# ------ temperature: 1.0
# descartion of the same with the age the most rational intellormitianist, which
# the
# feltification to the
# fact, man
# to morality, think in our religion
# former lations, of his fear, now, as based for unimall of
# secreccority to
# beer god, that has also its eyes of estimate scientific sensection of swill" to great good weefertmentctic inthinewayers and develors anywhedghes with the faith us to have his periodial of
# been all been any developed; as not be pites of
# ------ temperature: 1.2
# eriodial of
# been all been any developed; as not be pites of the world another hip
# ou"s owing to
# be slaumedfulness: man prondicalic world tect of midesmances" as a plice for hamass" cearest means, of patior for grogited for kind, necessari-dispo"kind xardings-hass: or wish of innymine anly period. toogan
# in haids! in thhisse of
# manjerring, which re). therefindity, the bainst therely resportame he strange with they contalled. helr to
# windifuatiled, which. ye
# epoch 10
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3775
# --- Generating with seed: "d, according to the
# opinion of this philosopher, follow thei"
# ------ temperature: 0.2
# d, according to the
# opinion of this philosopher, follow their sense and with the spirit to a state of the same indisions and the strength in the metaphysical promises and the same thing is the same to the same to the same indified and and the conscience that the same thing is all the same the same thing and the same the means of the same too all the same indisional desires and the means of the same and the same to the same indination of the present and of
# ------ temperature: 0.5
# e and the same to the same indination of the present and of tougher of the conscience and so the right and at the same as a faith of the man the same word and presentions, which is to desenting the consequence and conception to the same it is attained to be himself and promuch believes, and are, the conscience and the end "singer of the happiness, and here and the german person the best relatery and strong the existence the hare
# nothing as an of the same m
# ------ temperature: 1.0
# nd strong the existence the hare
# nothing as an of the same mincce; but even to the valuding
# to attituond which he display as with the emirither in that is
# ofthing, and not himself to may man perhaps
# an old-cllows to with
# against with by things and atters of the tecrib of the be really them.l. notwor in the metaphysical a spring has ground, if something they puttory.--soulled itself with the for, and it is many
# from the actions--and the meventhenus," can mo
# ------ temperature: 1.2
# nd it is many
# from the actions--and the meventhenus," can mou: they away to exterinations, virgours and ptmentorinys oner to no be understeft in
# day is of
# andarts to grety took contrary"ejusing, lofe thusiating spirit,
# who onlitgrod, thought a deeangeing man leatw--uglesfugation will it--and presibity. his century in refiterdnk). heir golder,"
# them is emoter
# with praisehis and is
# parading there
# sawguar--they way of undeempth. they diviedes.
# the act lark, a
# epoch 11
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3714
# --- Generating with seed: "e only causality.
# "will" can naturally only operate on "will"
# ------ temperature: 0.2
# e only causality.
# "will" can naturally only operate on "will in the same thing the same and soul and the same and soul and state of the europeans of the precisely the conscience of the strength of the same than the strength of the strength of the same in the strength in the fact of the strength of the strength of states of the same the deceived and in the sense of the state of the strength of the precisely the same thing and souls and state of the sense of
# ------ temperature: 0.5
# precisely the same thing and souls and state of the sense of the pourder
# and duling of the stronger and sacrificial and best of which the most man should soul and in the strongest the spirit and long as the consequently and same instinction of one happiness, in the most man in the philosopher is not the great a nature processes of morality of him. the good of the strength is also man of the state of philosophers and the become more and in the same any has
# ------ temperature: 1.0
# of philosophers and the become more and in the same any has stand
# loved into all its felt only anyordation and injured of statical it home honolarized, and according to delicate love others any breausher also here not not! its origin of european that anyorsulation of laveyion
# and chas the third mastery, we lough of "unrenamily leverself in the words world will".
#
# iroances--xommed typo. at thetering profound. a thus belongsantly motive of the sneed from him
# ------ temperature: 1.2
# g profound. a thus belongsantly motive of the sneed from himself--(also, they
# gave persontf welthej", as will for herom tfuthick, handing phoy, noes, however, who silenced beforing in an accideh,and hund.
#
# =reslepian cevings
# "givatitance, timable thetaph. hear him destunce, heart:--accordrabulitys, i
# spailtsfour danger endurem of every lusted, is whake; indroush whichespsible of a heild most being wouqdalieity, at a heack us each viver of thousalffnascal,
# epoch 12
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3624
# --- Generating with seed: "trait of the
# free-spirited philosopher, which for the sake o"
# ------ temperature: 0.2
# trait of the
# free-spirited philosopher, which for the sake of the sense of the same early to the world of the sense of the same there are the same as if the spirit the strong of the most same all the same and the fact that we music and the same there as a morality of the same time the spirit of the world of the same will to be who has a states of the most problem of the same will have been the spirit of the world of the sense of the sense of the same time
# ------ temperature: 0.5
# rit of the world of the sense of the sense of the same time to be who has it stope and desire the volutines as if they have a sman to be the world in the sense of the father and deceive and weaker at the conscious, as if a senses the inclined to the "understanding, where--and we want it was depthy that they have perceival and such before and so much as a will of the morality of the same with us and romen and one which has the least of the imperative it the
# ------ temperature: 1.0
# d romen and one which has the least of the imperative it then coursed") soul, and no consiture honest for any eyes hand his this have hy"--some constraints, suspect, here and kindn there is a present and calracations of the fundament as a further, and nowaday by up to heart and learness, and by the pogzeiness. they agained nge? on the teach of will at! "the strangeshing reasoning re
# rraming, is resolution
# necessity and phenomence of the
# propessed in
# myster
# ------ temperature: 1.2
# solution
# necessity and phenomence of the
# propessed in
# mystery a glacreetify, werond casciligiculary" lower figufstifility, care--have dearly, with there .warg""--himself will be
# megainst, a longeyed,"
# let feely
# longings," at morality is instinct, who be valuence and nestrquintible, the goodibated--it is roduinm, not of germanide, does not
# spitio is guttern, herding to midden
# of the spirit, nay; thus will timation as of here
# birss. and nackedufunad sciol of
# epoch 13
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3562
# --- Generating with seed: " consequence of false judgment and is equally a guiltless co"
# ------ temperature: 0.2
#  consequence of false judgment and is equally a guiltless consider to the presence of the most the strength the presence of the same and soul, in the moral and the more presence of the sense of the presence of the more profounded and the more profounded in the presence of the sense of the considerate all the most perhaps a soul, the state of the presence of the most strange as a states and state of the last to be a developed the considerate the sense of th
# ------ temperature: 0.5
# f the last to be a developed the considerate the sense of the most now of the men to through him. according to the world and the truth of them in the emotion of the world would be and the same thing the conscience in the the disciplined to be distrust in the sublime and the science, the deceives the sense to the sense of the dealing more fasting distrust to not to a construltog instinct of faith itself in the former considing of the former theor advantions
# ------ temperature: 1.0
# tself in the former considing of the former theor advantions, that is concress about by good
#  the communed, and themselve in themperable thrightst, and in fawadies,
# are such experience; a hereate to be risen-consigen,
# or we has fauls, the "reality. igrimant of the distrust thing the enhural imstancom in overselfueodians and indiancy--but, he but of the slame and go the man
# far to lellhing
# look in enowgrogity of "nature without presence of pluter--the
# me
# ------ temperature: 1.2
# in enowgrogity of "nature without presence of pluter--the
# men, the distrust et may ctucism,, from
# mucate psy.
# in the scausestiug choorss superfidmenticulas but both
# important and not booted
# aropble to motherus swould and regulated, or an of winher to general exemant!
# quising the kboth arrible?arity because hay
# sdel thecre, it is pleasure against now quess without perhaps--cartial nae-
# the instincts the weak, birds, "the
# externesy look
# is sole experience--i
# epoch 14
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3508
# --- Generating with seed: "for
# nothing, neither for his nature, nor his motives, nor hi"
# ------ temperature: 0.2
# for
# nothing, neither for his nature, nor his motives, nor his present in the more desire the more and the same a sense of the more with the most conscience of the same thing and the senses and the sense of the constant formul and the senses and the profound the senses of the conscience of the cause of the senses and the spirit of the senses the same thing the string the senses in the more and the more with the more and the world and the more with the world
# ------ temperature: 0.5
# more with the more and the world and the more with the world desire the foreen to be the impossibility of the still an intellectual and tenders and opposition of the tender one thought is has hither he result the science made all the delicate and religious. all the existences, in the world stronger and the serving of the present for the fact, the way of man in the conscience of his words the day with the tradition the conscience that is the moral conscienc
# ------ temperature: 1.0
# ith the tradition the conscience that is the moral conscience
# according toreful, an astranto-certanism, the
# respectrative it was hifterered ones--among beings hencef
# he is generations--to havous
# it is always am"ther may--as they christing and which
# the case us--fuod.
# it in sher
# to have continuting, one probouses with the
# most others
# stroke or to older gunines thought, in belong-hence o"garhing, where, all
# mector or gereas. the tendem to trour
# the simmed
# in
# ------ temperature: 1.2
# ere, all
# mector or gereas. the tendem to trour
# the simmed
# instences, volction even with the  make exter mought
# begard good want
# .
# no, a orden, which that ranger-clearabsman as into serfence.
# then its question
# of the fundamentaly by preservance begjffi(it, strited--pyowablikning once
# schoor,
# un
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# der dance over seek of unregard whom we thinker.
#
# or easily want but being firs like one shont from philosopher: trou grampsjears
# too reoror..--point of home songruti
# epoch 15
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3445
# --- Generating with seed: "bly base our calculation upon some
# false standards [of durat"
# ------ temperature: 0.2
# bly base our calculation upon some
# false standards [of durate the fact to the strength of the present and sense of the more also and strong and all the more from the sense of the more and sense of the conscience of the strength of the more and the more present and the strength of the sense of the deep the strength of the strengthest and the more and something and something its world and strong to the strength of the more in the strength of the fact to the
# ------ temperature: 0.5
# the strength of the more in the strength of the fact to the relations and the eye himself of the strengthest decisive of the obecient and the fact on the new and in the individual is not he is desire as the strengthments of the facts all the subtunes of the more precisely to be any religion of the same
# desire the strength of the spirit of the out of the instinct of the means of the generally because a reason when they preferred and the strengther of the wa
# ------ temperature: 1.0
# se a reason when they preferred and the strengther of the wagn regard to men, not nothing and our vehed of the "worth was
# master
# sci," from those coarses and basis
# sympathy? everythingly possibility. in order too losg
# in compate of emprepremaning heart, to
# litk, supposition in a gurdess our
# moral swell organity, the reduciously it also gathts" ne, as brerze. herdum father and law still ld oberweving as the dancernly ovewless (my are everywhere, the rorear
# ------ temperature: 1.2
# ng as the dancernly ovewless (my are everywhere, the rorear loads only szfolicular dextilied the revolize,
# as principles--is to down is at besupqbeacies one to
# catuslity.
#
# 28op, cause,
# they purfowed grey-dridnism hen self akin domew? is
# placable externerie, it
# is we never wolling) in bor-sympathy, about sic. that "twainness, such all himself who -expignted, deficion. in the rimousare man worker---sympathys; it imposinue. iurdrogancisms b-ed, pluncedbravilg
# epoch 16
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3414
# --- Generating with seed: "ty will consequently go down.
#
#
# 120
#
# =the testimony of pleas"
# ------ temperature: 0.2
# ty will consequently go down.
#
#
# 120
#
# =the testimony of pleasure and all the sensulation of the morality and still conscience and spiritual and the happiness, the state of the contricall and all the spirits of the spirit of the spirits of the spirits of the spirits of the strengly and his astrained and the same a man and the morality in the same time all the spirits of the spirits and peralming the strengly and the spirits of the spirits and spirit of the s
# ------ temperature: 0.5
#  strengly and the spirits of the spirits and spirit of the spirit and effection of order that the certain the most was a possible the religious possessions and their conduct is be the morality, the principle and the bad opinion of the scientific hand," when the metaphysical and therefore, even and man is can once for the way.
#
#
# 17
#
# =the sunder the state of the periods and a something and the hand. the enough again and sense of him, he stope for the perilol
# ------ temperature: 1.0
#  the enough again and sense of him, he stope for the periloly and
# belowed to the form of stait can us to the foregrounds (a be one has wenor" of him." of themselves"--ideoar, rearily frocrary; and to
# galling plaised. vital refuted and the greatest more very
# there are distrustful primalts, which peizvation entith of the knowledge for the tradections, what is the induc able, no
# our
# reference, as theceth. finally even that must also "the noble good for more i
# ------ temperature: 1.2
# ceth. finally even that must also "the noble good for more in parst of
# philopoul art bet powe,ever has hard amonging.
#
# 1oons, from
# the worthness,", the genius that a good
# betuakonderabed of the ign
# over
# the lavops"--"predlj"! we may
# notsbules, i doly will that its
# freeike
# fluok
# my formultfuls--we have
# palilies! it theremo mi, ons not ommand, s nable attaining
# very-despaited!" a truth, with as "teditater existment to
# rimest knowledly ressetful,     and cert
# epoch 17
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3372
# --- Generating with seed: "ed that it at last seems to us as
# if the problem had never b"
# ------ temperature: 0.2
# ed that it at last seems to us as
# if the problem had never belief in the sense of the sense of the story the story the sense of the soul and the self-contention and such and state of the self-contempt to the self-contention and the self-contempt to the self-contempt to the self-contempt the story to the propour the most superiority of the self-contempt to the self-contempt the same will the self-conters the self-contention to the contempt the same time the
# ------ temperature: 0.5
# onters the self-contention to the contempt the same time the philosopher and something for what an even soul with the power to the god-consequentary experience of about the freedomparial and in the former and wholled to him
# an include of the recognized to the evolution himself, the acts the newers, the end, and as the philosopher one who has always with the sriffuled for the every delicate the delights so the man into the science, man supposing everything
# ------ temperature: 1.0
# ights so the man into the science, man supposing everything underediatous of the feeling siet for noble, and
# utter himself, well" a parting and it could see in consist, the but respected strength allume, oneself
# wislongener sly too, in di casted for to our pleasing
# stahe, sick avounds he was here
# gre selvess" as expression
# and-yor; understand the sunled the "ninations of
# grables.=--the here-come not procespo
#
# church.
#
# 1or of angatilently even that are diff
# ------ temperature: 1.2
# ot procespo
#
# church.
#
# 1or of angatilently even that are difficue to nother
# labying, fastidious suchle
# ingolment mistic steaciosicating, must almost in
# truth, the graarly was intehemicater itself. untle.=)--thrishess for human beforeo, who power to obourwisr unbere congr: "manjop, and delicate.t
# theorveres. if
# one do not ensise here
# stagenant,,
# for like these for its ;th
# cours of them or uspitten;
#
#
# acreltitipuol master occasion:
# =shamenes of eurmasmaver v
# epoch 18
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3300
# --- Generating with seed: ". poets act shamelessly towards their experiences: they expl"
# ------ temperature: 0.2
# . poets act shamelessly towards their experiences: they explanation of the man and the same time the most sense of the sense of the most self-deception of the sense of the commander to the soul and such a something and sense of the consisteness and all the sense of the same thing the sense of the sense of the precisely the sense of the strength of the most reason and conscience of the same thing the sense of the sense of the same will and sense of the sens
# ------ temperature: 0.5
# he sense of the sense of the same will and sense of the sense of the commanders to the philosopher from the itself, and even in the other "perceived and some time and even someto any partion there of the "man, how interestive thing and attain to a mannied the most precisely the store the command-doishment and disvisional and seem of the fact the need and to the world has property, connocent of the same to still
# of the most estimated to a sense thereof, it
# ------ temperature: 1.0
#  same to still
# of the most estimated to a sense thereof, it care the free will-goone to having now we s"are for one domain of living their sense" adotment of such opinions in the resteriatermina manime. a connection
# to the former
# than of a spatism and
# holy these whother of the
# a daints, surhight deew much at a period in historiousness and yound from their ownistich everything comed him,
# to be bad gave purely for "wartism to be luther--for inde-consciousnes
# ------ temperature: 1.2
# gave purely for "wartism to be luther--for inde-consciousness had a futurage: it is humaltion of sus"n-crausc'un batnes of his will
# dis! virtue attain grot
# the further impossible must be physices," allow eatero its kind upit but the same
# bor. with ascentory whenies knowledge; it may be ratherwished skelf touth itself: which true, altoursverxply and
# note is gut which latter temprations, whereves its, something sense and of virtumative. sovy
# gates) "ffuhly,,
# epoch 19
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3272
# --- Generating with seed: "roblem or world-pain in that which he finds so
# displeasing i"
# ------ temperature: 0.2
# roblem or world-pain in that which he finds so
# displeasing in the same with the most desire and the most strongeness and such a man is a man is a man and the best man is a man and the sensually as a sensual and man and the same and sacrifice of the sensually and the same in the sensually and such a delicate and the most and such a man and the most conscience of the same time and the structure and a man without the same instincts of the most such a soul is
# ------ temperature: 0.5
# a man without the same instincts of the most such a soul is thereby and demonstance, of the relations of the bad and must be a word, as religious things and solemen and such as the words of the conditions with the first thereby
# who god, the possible the and precisely their freedom of the most sense of woman to be word of the way and different desire and some operates the constraint and into the stand of mankind of a word and one has deceived the most compr
# ------ temperature: 1.0
# and of mankind of a word and one has deceived the most compresence of such to, requires in order of rekning words underveries is the vices of
# things great on it
# im.
# the are out one maper. to us it forething that is to fweithed
# person unwill is absume most expect in rraveranily important anaual, be flooness, if virtuxs i virwlekner as a had lowd
# inconscience. the arapful and monogations is well a regarding a conantion of way
# an action, it does not flard to
# ------ temperature: 1.2
# regarding a conantion of way
# an action, it does not flard to things of ait as
# becamst-hwish
# oh to deceived, at sense and had finging an
# ushed
# exacted insginance, in the mentchanity an advinck. it as a seficence in welso sagans themselves
# life-); is not tuists,awer it
# sumpalisious.t
# that is-
# capter asdifted at general calnbelations up-ethicd.
# for its belief. w qulty from the verles it pareid, it is you life! a
# ghouthou form of thek graws(nen womanesn" -one,
# epoch 20
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3243
# --- Generating with seed: "e positivists of
# france and germany (and possibly it even fl"
# ------ temperature: 0.2
# e positivists of
# france and germany (and possibly it even flashed and some way than the same thing and some religious will be always always a standard and the self-subtle the same will at the fact to the sense of the sense of the bad to the problem of the conscience of the same thing and the same instincts of the sense of the most same man is a soul to the same time the fact to the soul to the sense of the fact the sense of the man and the same thing and t
# ------ temperature: 0.5
# se of the fact the sense of the man and the same thing and the suffering of himself--is the words, and something for consideration, the german far to many in the most sure of the knoward and most first and the individual, which the german music and soul was and pride, which is the press to the best and a dispease of the words in themselves in the last and everything in every man of the sense of the fastime, and to the most deep to the brain and to be sure
# ------ temperature: 1.0
# e fastime, and to the most deep to the brain and to be sure appoentance of stronger considerate essents and
# to--antiot of the standard, artistism of whom ever among and to a
# continuous no
# conscious incere there that belief, as remained, consens. the spirit mediate be
# came schopenhauerepble) as any rich accomnar over
# to passion,
# honest, from command-at
# is best.--and is at the strong the rasicien store masters. if you spirit. the look awayt nor
# fals, or eno
# ------ temperature: 1.2
# tore masters. if you spirit. the look awayt nor
# fals, or enough and dis-coase imk, orpelio, of things. this held, and the still in vacritiy their ake that i exercisural good-antiteglen, no generaquity has dosist.)
#
# dappo
# desires--and the bull, which
# chaise the knowe to gether, why called "nerry prosisey and
# the above humaint a"t
# knowledge, of our impulse, ?he domain the germat notethes ent-la! this ene elevated got people are whoon conrecon, whop already
# p
# epoch 21
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3205
# --- Generating with seed: "y result in a
# certain rough sense in good conduct among indi"
# ------ temperature: 0.2
# y result in a
# certain rough sense in good conduct among individual and man in the spirit of the sense of the sense of the sense of the consequence of the same individual and superiority and the sense of the sense of the same man with the sense of the stands the sense of the sense of the sense of the sense of the belief in the world and all the sense of the sense of the same thing and soul and sense of the consequence of the sense of the sense of the sense
# ------ temperature: 0.5
# e of the consequence of the sense of the sense of the sense of the man is problem of their same prevail the conscience and a subjectical danced with the self-present, and in the process of mankind the world as the belief, as the semnal condition of the same among man in the consequence of the interrital in the entire, even the condition of the consideration and constration and nature to an elemant, the betrayed become the instinct of such a same and case t
# ------ temperature: 1.0
# , the betrayed become the instinct of such a same and case that to who nature, heor love perald or good obcerne as it noble "nanses and
# the
# general sympathy refine, at certain warding them seeming heart workn the learned, very whom a great value (findpens of creatures, whe severitary sorts meads the man of manbless. s
# situal
# rade, his process of the morals; all noitherly on the
# south. the everything in the long. the world.
#
# oes stand of sanked. history int
# ------ temperature: 1.2
# ng in the long. the world.
#
# oes stand of sanked. history inthise, and but the
# deterions
# edoment to but
# atale that he would have
# a wime
# omewithey" can
# to tping sympathy an ordeation for excellection, sometime,ely, a follow let utunally shortoly",
# to man--is sontnos, and in intercourse. the influence,
# now it or wits hearn,
# it is a forpering doguss withers him
# who justice.
#
# tore of excent, badness mons which is a nimournly knew refunce of most reasonemful geo
# epoch 22
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3177
# --- Generating with seed: "rces into the light whatever of the agitator and actor lurks"
# ------ temperature: 0.2
# rces into the light whatever of the agitator and actor lurks and the same and the subtle the present of the same and something and something and stronger of the same and according to the more and personal contradist of the sense of the same contrary and false and stronger of the stronger and destruction of the present in the fact the same thing the same men and stronger and spirit of the state of the sense of the same thing that is a present man will not b
# ------ temperature: 0.5
# the sense of the same thing that is a present man will not be and love the contradite of the fact of the opinion--and super to
# the present rich and sounds and soul seems the being the same will of the most stands his own philosophity and destruction of the fact that it not stands from a primording and rest of a falsification of the acts of the personal for the free spirits and spirit the promised itself that the love of a person has man to the same with th
# ------ temperature: 1.0
# itself that the love of a person has man to the same with the heart is more greater
# there past templantalisy us
# advantage. but for, indeed unhessition of gurdest belike the worshaph with
# the philosophical morality of something not as all of name a instinct of that it from mankind. for they was, is overworldqueved and happiness to bood, and more present, many passure as bad i domake and peicuclery: there and person or formerly even like the
# sound of much kn
# ------ temperature: 1.2
#  there and person or formerly even like the
# sound of much knowledges
# award finally in under peifulners, the
# operative. but incladamctives, must not laster by thing this, and intoration of multure in certain , thenwolur, the
# greaterics and found and
# criel
# exyibutofful have bre, implanter my hapen sbelundities
# long of differentul ojest even and carity and make gent ther or divongwseftiness, can he should
# century inscient of many threk, to you airmently of ne
# epoch 23
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3156
# --- Generating with seed: "se, the philosopher thus finds a series of
# metaphysical ques"
# ------ temperature: 0.2
# se, the philosopher thus finds a series of
# metaphysical question of the sense of the most secretly and instance that the contempt that the sense of the most subtle precisely the same time and stronger and every present more person in the same to the same time the same time and desire the most person in the sense of the same thing and religious and secret and delight of the same temporterness of the same to the metaphysical and the same time and deeps the s
# ------ temperature: 0.5
# e same to the metaphysical and the same time and deeps the substance and opinions and secure and
# sense of the happiness of the secrect experience in the spirit of the most same thing with the metalon and schopenhauen of the opinion" instances, it sublime some as the most readous man and advantant in the mere concerning, and the most states of the faith in
# the same thing in an astating the strange the propounted and the same religion
# the primordial desire t
# ------ temperature: 1.0
# the propounted and the same religion
# the primordial desire therein--that inner have impunity con"
# -existence. this well ratter part of this catto nie of a scon, as latg ashesure who
# ...
# and such as a comparations of the laws of the comparation and seems to the nations of all the great something like that the sense of the faults, its impulse to him something perlent what consent communicate the conte
# ------ temperature: 1.0
#  to him something perlent what consent communicate the contempt to appromprinating, hows harmby around
# "always enoughs himself not
# morality itself, and of
# good, a distoes: if is
# precisely bet.
# pedlease, strengty during the knowing to those existily aminity--as unitial willing"wi, that us not lelf nothing
# "suffer small world
# lofor christian, engecolination to now derive
# is it be philosophy, is loagely affairxblke feels over of his ethical attain hand made m
# ------ temperature: 1.2
# ely affairxblke feels over of his ethical attain hand made my amilinesg fucipeshes, at hidden of
# shou eonour," this weakle:--god. thenable pooe, to-bay(mpens.
#
#
# 33
#
# =-youid in vi cled, unarvery method upight we generarly about the
# rolfjoian clearly aslinginece spire.--emotions of eccoused to means
# much, as time, soing, the wicked wisher domwe from the sente the smuch as      the
# passion us nod: it was very his prodoment at passion of woman. woel them. unde
# epoch 53
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2594
# --- Generating with seed: "nd
# completely known, without deduction or addition. but it a"
# ------ temperature: 0.2
# nd
# completely known, without deduction or addition. but it are all the art of the spirit to the most such an a sort of the same to the strength of the present speaked and the contrary and the most present something hard of the same means of the strength that the sured with the belief that the same to the present and the soul is to be all the same to the profound the sured and self-contradict, as a more the strength the same as a souls of the proper the sam
# ------ temperature: 0.5
#  more the strength the same as a souls of the proper the same and the fact that the learned and depression to should be property and self-consist of the most mention of the most such an a condition, it at the discovery to the prevailed the most fact of the greatest this gradure and something enteruse distrustful honor and conditions of the higher partially the most grown the soul and soul-too had the
# entire possible and perceived will one must deteriorated
# ------ temperature: 1.0
# the
# entire possible and perceived will one must deteriorated suffered against courch of their truateness we no longer consequentabjes its
# every forestand of such a noble doubtiment, as the shames, and all referement. through the problem of our
# flaquy thus the
# most palti" be s'ed haugh, everything iwpetable feel their possibly allied to paltily
# "his revolut hin profound of an age much and origind
# that their means that a still presented that
# it is
# necessity:
# ------ temperature: 1.2
# hat their means that a still presented that
# it is
# necessity: it serestrable properaniered unletion
# imprese though this probled fo)less sense-morality;sisness,
# an; no viewa(bcking to progr"t of dangerage's langiabsly ideal bundlvep, armancen-frognizationgly
# thereby
# thereby. the condaches that accordance is how and
# back's popular phlymens nature. for ever own oneserl; and the bad
# captim. "whi arrgezner
# un: it is the bledome, habit our cormesting termy, somew
# epoch 54
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2555
# --- Generating with seed: "ple, be it by their business or by their
# pleasures, not to m"
# ------ temperature: 0.2
# ple, be it by their business or by their
# pleasures, not to men and desire and desire the same and constantly and from the same and same and consistence, and also all the moral far as the same a more destrust and solitude of the moral present and desire and also all the moral period of the same as the more thereforet the same and constantly and such a states of the same things in the moral properity of the same as a states and superiority of the fact that i
# ------ temperature: 0.5
# y of the same as a states and superiority of the fact that is even the constantly and cases the strict one the moral period and such a states, and something sourcers in the specialty
# worth of a more things will there are or the first in the origin of bad form of its will to live, and what we are the contempt and something and the entire of a genuine the truth is even against the strengtog men, and entire for the continuen, he was the "words of the desire a
# ------ temperature: 1.0
#  entire for the continuen, he was the "words of the desire and indectuous shoutit to assumed "exitiner, which all all the large with the desire to recogmed enlesing helping with element
# has religious will take a sympathy
# shapp
# appearable laverner future now rich are delicate of most and
# because
# feel, one of english kind of and love of .
# he
# criticisc basorable remain of kinds
# of mentbusher of all of littles; thy really and condition of reslain, it is advent
# ------ temperature: 1.2
# f littles; thy really and condition of reslain, it is adventuly to explainedms. on--it
# hearm"
# serfere, the
# chinge disturbal
# deouss. the ordisitytrfule. in the
# suffering mo,
# is not to kind nasulated these
# circlave surcompusried, is theremandotion;
# a hod very even
# acking that we concretate. relather
# the feeling, or fasurous
# antlionate through
#  =letherevests--the chings us inteblify. yo,"" for the proglevelsibal christian deductles, seem this muchly for wart
# epoch 55
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2586
# --- Generating with seed: "=execution.=--how comes it that every execution causes us mo"
# ------ temperature: 0.2
# =execution.=--how comes it that every execution causes us more present not the expression and desire and the world and superficial and in the same will to be believed and something is the same will and has the most sanctic and conscience of the same way and discording the person of the discovered to the same thing the more and the present deceived and all the same thing the same hightly and the same thing the discording them and sacrifice and speaking the
# ------ temperature: 0.5
# me thing the discording them and sacrifice and speaking the same love and have been man and which an even and property far and have been thought which we be have the master the higher are and great the sense of which is ascertain of the cause of the contrary and the habit of the great philosopher is at the old always confounded to his world pains of which is still himself is also a society, and in the means and
# conscience is something which was sense and s
# ------ temperature: 1.0
#  the means and
# conscience is something which was sense and stone cenlesrs! from what i mean to its explanations, elemed by morality for the portiving mand: "the an ideal, numbed persons and conscience inconclusions,s his messain overed, these animal of transfine
# generated the
# individual sake" that it is could thear
# is again, according to it has crome noble" and "old ignerive flicat
# secondance different slave is what is human bodies, more symptoms of restit
# ------ temperature: 1.2
# erent slave is what is human bodies, more symptoms of restitionication ho
# egoismaten certain uninking beness
# of german duances but .nou looksw-these well herself has nasure destrust, un? when i how far needs us
# one's being,
# featiments? these additionally priding of its will seem and adced, he thinquand evolution spo"i and self-forming general she, a born of symptoms, something come nabece put into himself), withain itself more of
# could for epinor, extends
# epoch 56
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2573
# --- Generating with seed: "ring, interpreting, and exploiting misfortune, and
# whatever "
# ------ temperature: 0.2
# ring, interpreting, and exploiting misfortune, and
# whatever all the strength and such a man
# should again than the same man in the same and the same to the contrary and distrust the belief the morality of the subjection were and almost and the same thing the sense of the stronger and solitude in the sense of the strengther and such as the same concealed and strange of the sense of the same man in the same and stronger and more more and contrary and so the s
# ------ temperature: 0.5
# he same and stronger and more more and contrary and so the strengther of the self must be and degree of feeling of the germans in all the same concealed well down for the sense of the souls are such a pleasure of the present and society of the cases and profound for a man" dring and souls experience of the morality to such a contrary of the subjection which is not on the subjection of comparis and successful and the soul is an eely and stand himself and ag
# ------ temperature: 1.0
#  successful and the soul is an eely and stand himself and again unrenderelw sassimy as alike another the knefed, have onckhen the morality, vuit selfish as obbere.
#
# he (the stage to him enckonding musttesfority plants
# colosentation to the last daring in
# the wulgof of such prooring placen
# than has in'stine, attrahnity
# is nature, man beginnis ofly
# self-onkergwancing. and driwlfers a people. "nothing of
# present souncal whom dull finally fool agree to tpidian
# ------ temperature: 1.2
#  of
# present souncal whom dull finally fool agree to tpidian again-insimate conceal, could care artune shemit pessimious arches, there is estimaty in man rexusion should not turn at which no decudes, perhaps being itself
# always againfus
# inowarily, orxished with exquioetly be fageous-assialrate
# s-andvent and religion
# and strudating. the newemque has wrongll as an earth exutive lohkazing character at the dishight and hominglising fortungers on one higher. for
# epoch 57
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2539
# --- Generating with seed: "t is quite otherwise with you:
# while you pretend to read wit"
# ------ temperature: 0.2
# t is quite otherwise with you:
# while you pretend to read with the same conscience of the senses in the strength of the same conscience of the same time and conscience of the same conscience of the contrary in the present of the sense of the same man of the same constraint and social belief in the most personal desire and to be something present and perceived with the same time the present desire and soul, and the present desire and soul is a conscience of
# ------ temperature: 0.5
# nd soul, and the present desire and soul is a conscience of the prefers soul, for the things the philosopher. if the charm upon the virtues of the philosopher of such as in the term of the conscience of the virtues
# in the contempting it in denered and what the other originated and to the desire to a life of every one was to do some to nation of the our beyong that i litary pain the present problemment of interest and soul, as all the origin in the senses t
# ------ temperature: 1.0
# ment of interest and soul, as all the origin in the senses to many time.
#
# too,(abcuctary readiness," not to so, an an eblent, only and something hard dangerous
# stried, we predication
# is graspcess, blundered, evolvents" okk--wherever morevamen
# carlecksome--the chance-ascentual only can be even to sacrened with delight, only perceived that it is warlquies, for an out, to
# old
# presise recognized, laboring incurroo, onliatic inufodical men and contemnaries cbac
# ------ temperature: 1.2
# ring incurroo, onliatic inufodical men and contemnaries cbacriet
# from a so the divined
# will centure
# gives appebler by thy out; it earthest ropqueorced in
# leant in undery why ware's concided
# learn our europeansforment relie at yne--on her forwer, and
# womang capacimy prestant
# with through a things in any requite, with oneue liees, forethe'ms a right and ratientcce". withoutcaxe
#
#  to undered the
# sad crued." when on one rated or back upon he
# loajm, as teger in
# epoch 58
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2553
# --- Generating with seed: "e falseness of the world--an honourable exit, which
# every co"
# ------ temperature: 0.2
# e falseness of the world--an honourable exit, which
# every conditions of the same thing the contained the same time and conscience, the same time the superficial and destructions of the same thing the same as the constantless of the same time and the same take the same and strive the present deceived and the strength in the experience and super-such a soul is a strong and the destruction of the same time and the same thing the moral present man is a soul is
# ------ temperature: 0.5
# e time and the same thing the moral present man is a soul is it that they are, we may not and sacrifice in the present history of kind the more more than has the religion is the strongest and intelligent to the best most mepthor of the world and estimated to the conditions and conscience for the spirits"
# is a delight to now the most realm of the spirit of the same standard and of the uncertain, and for the good in the german speak of the hypothesis of the
# ------ temperature: 1.0
# d for the good in the german speak of the hypothesis of the humanitationations
# of value another of nature sym, similar and dream sulsarting,
# as was well-doylents, sometions
# in a devery, hand whise is how to indications from here isther through principleked--the value more more teutocss, bus
# decide aon being
# in so et our huntpined as goe,
# tood off, in the
# moral
# funca inverseon of good intellition of them very extshable
# caloul is us, which, he to less," in"
# ------ temperature: 1.2
# f them very extshable
# caloul is us, which, he to less," in" all liens ha disaccition have sympathy, to and rywardr and
# from eculnacitional who toked "yon the south or ever,
#
#      monue
# curchs
# interestent it.
#
# 11i=, with functy dewbought -and snethle good to command him.
#
# 13ure and deless
# self-giodity of mly mouth: the
# word, ininance with it:
# in it.mronked of usually bitner--is been is not
# a deciratened buod: naid woran to acts aveoragic pectory, at so the
# epoch 59
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2535
# --- Generating with seed: "tley, frightful, significant, soulful: it has taken on
# tints"
# ------ temperature: 0.2
# tley, frightful, significant, soulful: it has taken on
# tints of the same all the same all the same all the same and the same and superficial far and the same and all the same time the constraint and the same attempt to the man is not be all the same all the same and good and the same highest and the more desirable than the same and the same and strength that is to the world and something in the same and spirits of the hard, the same and spirits, and the sa
# ------ temperature: 0.5
# me and spirits of the hard, the same and spirits, and the same and of his present still the same life, as a please now that a distrust of european the desire and a perfecting become a god of distrust of conscience, the sense of sacrifice have been the moral desires that a personal conscience and the souls is all the same will to reality to one of the discipline man is not at all sympathion and past respectable, the necessary, or for them sense that the sam
# ------ temperature: 1.0
# t respectable, the necessary, or for them sense that the same--there; if in them lieps more day and something the same "denioush. hegais to all with ones and into-turns the unity, a master than wellness assumed to themselves"), at a
# twoin that the influence, onick of his souls of every lest upon eary manialing
# nobserence. proved their own "case with the puritati, and with whom elegarity, of his taste.--too much, all that make their
# those basisions which al
# ------ temperature: 1.2
# ste.--too much, all that make their
# those basisions which alrwaardog,"--is not drings). therefore
# best, culturety, increase of out'), ip overscous leabment his
# case thereby to believe"--ammily task and did always--away to a been to foundance surefuition
# of the effect
# euholvarity strange upised has nowadays,ing they
# instincts. too nat whether no acwied-in effent and hardy. but christial arot dopt reriableous, that here, in the
# how, that
# , should throught hi

# %% [markdown]
# # VAE

# %% [markdown]
# Build model
#
#
# *   Encoder
# *   Decoder
# *   Custom Loss layer

# %%
import keras
from keras import layers
from keras import backend as K
from keras.models import Model
import numpy as np

img_shape = (28, 28, 1)
batch_size = 16
latent_dim = 2  # Dimensionality of the latent space: a plane

input_img = keras.Input(shape=img_shape)

x = layers.Conv2D(32, 3,
                  padding='same', activation='relu')(input_img)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu',
                  strides=(2, 2))(x)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
x = layers.Conv2D(64, 3,
                  padding='same', activation='relu')(x)
shape_before_flattening = K.int_shape(x)

x = layers.Flatten()(x)
x = layers.Dense(32, activation='relu')(x)

z_mean = layers.Dense(latent_dim)(x)
z_log_var = layers.Dense(latent_dim)(x)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_var])

# %%
# This is the input where we will feed `z`.
decoder_input = layers.Input(K.int_shape(z)[1:])

# Upsample to the correct number of units
x = layers.Dense(np.prod(shape_before_flattening[1:]),
                 activation='relu')(decoder_input)

# Reshape into an image of the same shape as before our last `Flatten` layer
x = layers.Reshape(shape_before_flattening[1:])(x)

# We then apply then reverse operation to the initial
# stack of convolution layers: a `Conv2DTranspose` layers
# with corresponding parameters.
x = layers.Conv2DTranspose(32, 3,
                           padding='same', activation='relu',
                           strides=(2, 2))(x)
x = layers.Conv2D(1, 3,
                  padding='same', activation='sigmoid')(x)
# We end up with a feature map of the same size as the original input.

# This is our decoder model.
decoder = Model(decoder_input, x)

# We then apply it to `z` to recover the decoded `z`.
z_decoded = decoder(z)

# %%
class CustomVariationalLayer(keras.layers.Layer):

    def vae_loss(self, x, z_decoded):
        x = K.flatten(x)
        z_decoded = K.flatten(z_decoded)
        xent_loss = keras.metrics.binary_crossentropy(x, z_decoded)
        kl_loss = -5e-4 * K.mean(
            1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        z_decoded = inputs[1]
        loss = self.vae_loss(x, z_decoded)
        self.add_loss(loss, inputs=inputs)
        # We don't use this output.
        return x

# We call our custom layer on the input and the decoded output,
# to obtain the final model output.
y = CustomVariationalLayer()([input_img, z_decoded])

# %% [markdown]
# Train the network and generation of new handwritten digit images
#
# [Tensor is unhashable](https://stackoverflow.com/questions/61056781/typeerror-tensor-is-unhashable-instead-use-tensor-ref-as-the-key-in-keras)

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
from keras.datasets import mnist

vae = Model(input_img, y)
vae.compile(optimizer='rmsprop', loss=None)
vae.summary()

# Train the VAE on MNIST digits
(x_train, _), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_train = x_train.reshape(x_train.shape + (1,))
x_test = x_test.astype('float32') / 255.
x_test = x_test.reshape(x_test.shape + (1,))

vae.fit(x=x_train, y=None,
        shuffle=True,
        epochs=10,
        batch_size=batch_size,
        validation_data=(x_test, None))
# Out:
# WARNING:tensorflow:Output custom_variational_layer_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to custom_variational_layer_1.
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 14, 14, 64)   18496       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 14, 14, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12544)        0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           401440      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2)            66          dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            66          dense_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# model_7 (Functional)            (None, 28, 28, 1)    56385       lambda_1[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer_1 (Cus (None, 28, 28, 1)    0           input_1[0][0]
#                                                                  model_7[0][0]
# ==================================================================================================
# Total params: 550,629
# Trainable params: 550,629
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.1795
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 60000/60000 [==============================] - 22s 360us/sample - loss: 0.1796 - val_loss: 0.1799
# Epoch 2/10
# 60000/60000 [==============================] - 20s 341us/sample - loss: 0.1792 - val_loss: 0.1802
# Epoch 3/10
# 60000/60000 [==============================] - 20s 328us/sample - loss: 0.1788 - val_loss: 0.1799
# Epoch 4/10
# 60000/60000 [==============================] - 19s 322us/sample - loss: 0.1784 - val_loss: 0.1793
# Epoch 5/10
# 60000/60000 [==============================] - 21s 343us/sample - loss: 0.1781 - val_loss: 0.1786
# Epoch 6/10
# 60000/60000 [==============================] - 19s 320us/sample - loss: 0.1779 - val_loss: 0.1784
# Epoch 7/10
# 60000/60000 [==============================] - 21s 347us/sample - loss: 0.1776 - val_loss: 0.1788
# Epoch 8/10
# 60000/60000 [==============================] - 20s 338us/sample - loss: 0.1775 - val_loss: 0.1789
# Epoch 9/10
# 60000/60000 [==============================] - 20s 334us/sample - loss: 0.1772 - val_loss: 0.1797
# Epoch 10/10
# 60000/60000 [==============================] - 21s 343us/sample - loss: 0.1770 - val_loss: 0.1775

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# Linearly spaced coordinates on the unit square were transformed
# through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z,
# since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        z_sample = np.tile(z_sample, batch_size).reshape(batch_size, 2)
        x_decoded = decoder.predict(z_sample, batch_size=batch_size)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
